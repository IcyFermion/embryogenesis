# %%
import numpy as np
import pandas as pd

# %%
tracking_df = pd.read_csv("./data/embryo1/tracks.txt", sep="\t")

# %%
tracking_df
# Out:
#           t      z      y      x  cell_id  parent_id  track_id  radius  \
# 0         0  117.0  120.0  194.0        1         -1         1    30.5
# 1         0  122.0  112.0  333.0        0         -1         0    17.5
# 2         1  117.0  114.0  179.0        3          1         1    15.5
# 3         1  118.0  115.0  333.0        2          0         0    17.5
# 4         2  112.0  121.0  177.0        5          3         1    18.5
# ...     ...    ...    ...    ...      ...        ...       ...     ...
# 110894  378  161.0  167.0  271.0   110786     110195         0     8.5
# 110895  378  159.0  155.0  299.0   110414     109822         1     8.5
# 110896  378  151.0  156.0  328.0   110799     110209         0     6.5
# 110897  378  138.0  181.0  315.0   110790     110199         0     6.5
# 110898  378  151.0  176.0  317.0   110601     110010         0     8.5
#
#               name  div_state
# 0               AB          0
# 1               P1          0
# ...

# %%
len(tracking_df["cell_id"].unique())
# Out:
# 110899
